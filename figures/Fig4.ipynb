# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from matplotlib.patches import Ellipse

# %%
data_L8=pd.read_csv("..\\data\\correlators_Z2\\Ising_DMRG_L8.csv")
R2_L8=data_L8["R2"]
R4_L8=data_L8["R4"]
R6_L8=data_L8["R6"]
R8_L8=data_L8["R8"]
ps = data_L8["p"]

# %%
data_L16=pd.read_csv("..\\data\\correlators_Z2\\Ising_DMRG_L16.csv")
R2_L16=data_L16["R2"]
R4_L16=data_L16["R4"]
R6_L16=data_L16["R6"]
R8_L16=data_L16["R8"]
ps = data_L16["p"]

# %%
data_L32=pd.read_csv("..\\data\\correlators_Z2\\Ising_DMRG_L32.csv")
R2_L32=data_L32["R2"]
R4_L32=data_L32["R4"]
R6_L32=data_L32["R6"]
R8_L32=data_L32["R8"]
ps = data_L32["p"]

# %%
data_L64=pd.read_csv("..\\data\\correlators_Z2\\Ising_DMRG_L64.csv")
R2_L64=data_L64["R2"]
R4_L64=data_L64["R4"]
R6_L64=data_L64["R6"]
R8_L64=data_L64["R8"]
ps = data_L64["p"]

# %%
colors4 = plt.get_cmap("Oranges")(np.linspace(0.1, 1.0, 5))
fig, ax = plt.subplots(1,figsize=(6,3))
ps=np.linspace(0.01,16,20)
ax.set_title("Rényi-8 correlator", fontsize = 18)

ax.plot(data_L8["p"],R8_L8,color=colors4[1],zorder=1, linewidth = 2.5)
R88=ax.scatter(data_L8["p"],R8_L8, marker="o", color=colors4[1], edgecolor=colors4[0],label = "N=8", linewidth = 1, s = 90)

ax.plot(data_L8["p"],R8_L16,color=colors4[2],zorder=1, linewidth = 2.5)
R816=ax.scatter(data_L8["p"],R8_L16, marker="o", color=colors4[2], edgecolor=colors4[0],label = "N=16", linewidth = 1, s = 90)

ax.plot(data_L32["p"],R8_L32,color=colors4[3],zorder=1, linewidth = 2.5)
R832=ax.scatter(data_L32["p"],R8_L32, marker="o", color=colors4[3], edgecolor=colors4[0], linewidth = 1,label = "N=32", s = 90)

ax.plot(data_L64["p"],R8_L64,color=colors4[4],zorder=1, linewidth = 2.5)
R864=ax.scatter(data_L64["p"],R8_L64, marker="o", color=colors4[4], edgecolor=colors4[0], linewidth = 1,label = "N=64", s = 90)

ax.legend()
ax.set_yscale("log")
ax.set_xlabel("p", fontsize = 20)
ax.set_xlim(4,11)
ax.set_ylim(10e-10,1)

ax.legend(fontsize = 18, frameon = False)
ax.set_yticks([1,10e-5,10e-10])
#ax.set_xticks([0,4,8,12,16])
ax.set_yticklabels([r"$10^{0}$",r"$10^{-5}$",r"$10^{-10}$"])
ax.tick_params(labelsize = 18)

# %%
colors4 = plt.get_cmap("Oranges")(np.linspace(0.1, 1.0, 5))
fig, ax = plt.subplots(1,figsize=(6,3))
ps=np.linspace(0.01,16,20)
ax.set_title("Rényi-6 correlator", fontsize = 18)

ax.plot(data_L8["p"],R6_L8,color=colors4[1],zorder=1, linewidth = 2.5)
R88=ax.scatter(data_L8["p"],R6_L8, marker="o", color=colors4[1], edgecolor=colors4[0],label = "N=8", linewidth = 1, s = 90)

ax.plot(data_L16["p"],R6_L16,color=colors4[2],zorder=1, linewidth = 2.5)
R816=ax.scatter(data_L16["p"],R6_L16, marker="o", color=colors4[2], edgecolor=colors4[0],label = "N=16", linewidth = 1, s = 90)

ax.plot(data_L32["p"],R6_L32,color=colors4[3],zorder=1, linewidth = 2.5)
R832=ax.scatter(data_L32["p"],R6_L32, marker="o", color=colors4[3], edgecolor=colors4[0], linewidth = 1,label = "N=32", s = 90)

ax.plot(data_L32["p"],R6_L64,color=colors4[4],zorder=1, linewidth = 2.5)
R864=ax.scatter(data_L32["p"],R6_L64, marker="o", color=colors4[4], edgecolor=colors4[0], linewidth = 1,label = "N=64", s = 90)

ax.legend()
ax.set_yscale("log")
ax.set_xlabel("p", fontsize = 20)
ax.set_xlim(4,11)
ax.set_ylim(10e-10,1)

ax.legend(fontsize = 18, frameon = False)
ax.set_yticks([1,10e-5,10e-10])
#ax.set_xticks([0,4,8,12,16])
ax.set_yticklabels([r"$10^{0}$",r"$10^{-5}$",r"$10^{-10}$"])
ax.tick_params(labelsize = 18)

# %%
colors4 = plt.get_cmap("Oranges")(np.linspace(0.1, 1.0, 5))
fig, ax = plt.subplots(1,figsize=(6,3))
ps=np.linspace(0.01,16,20)
ax.set_title("Rényi-4 correlator", fontsize = 18)

ax.plot(data_L8["p"],R4_L8,color=colors4[1],zorder=1, linewidth = 2.5)
R88=ax.scatter(data_L8["p"],R4_L8, marker="o", color=colors4[1], edgecolor=colors4[0],label = "N=8", linewidth = 1, s = 90)

ax.plot(data_L8["p"],R4_L16,color=colors4[2],zorder=1, linewidth = 2.5)
R816=ax.scatter(data_L8["p"],R4_L16, marker="o", color=colors4[2], edgecolor=colors4[0],label = "N=16", linewidth = 1, s = 90)

ax.plot(data_L32["p"],R4_L32,color=colors4[3],zorder=1, linewidth = 2.5)
R832=ax.scatter(data_L32["p"],R4_L32, marker="o", color=colors4[3], edgecolor=colors4[0], linewidth = 1,label = "N=32", s = 90)

ax.plot(data_L64["p"],R4_L64,color=colors4[4],zorder=1, linewidth = 2.5)
R864=ax.scatter(data_L64["p"],R4_L64, marker="o", color=colors4[4], edgecolor=colors4[0], linewidth = 1,label = "N=64", s = 90)

ax.legend()
ax.set_yscale("log")
ax.set_xlabel("p", fontsize = 20)
ax.set_xlim(4,11)
ax.set_ylim(10e-4,1)

ax.legend(fontsize = 18, frameon = False)
ax.set_yticks([1.1,10e-2,10e-4])
#ax.set_xticks([0,4,8,12,16])
ax.set_yticklabels([r"$10^{0}$",r"$10^{-2}$",r"$10^{-4}$"])
ax.tick_params(labelsize = 18)

# %%
colors4 = plt.get_cmap("Oranges")(np.linspace(0.1, 1.0, 5))
fig, ax = plt.subplots(1,figsize=(6,3))
ps=np.linspace(0.01,16,20)
ax.set_title("Rényi-2 correlator", fontsize = 18)

ax.plot(data_L8["p"],R2_L8,color=colors4[1],zorder=1, linewidth = 2.5)
R88=ax.scatter(data_L8["p"],R2_L8, marker="o", color=colors4[1], edgecolor=colors4[0],label = "N=8", linewidth = 1, s = 90)

ax.plot(data_L16["p"],R2_L16,color=colors4[2],zorder=1, linewidth = 2.5)
R816=ax.scatter(data_L16["p"],R2_L16, marker="o", color=colors4[2], edgecolor=colors4[0],label = "N=16", linewidth = 1, s = 90)

ax.plot(data_L32["p"],R2_L32,color=colors4[3],zorder=1, linewidth = 2.5)
R832=ax.scatter(data_L32["p"],R2_L32, marker="o", color=colors4[3], edgecolor=colors4[0], linewidth = 1,label = "N=32", s = 90)

ax.plot(data_L64["p"],R2_L64,color=colors4[4],zorder=1, linewidth = 2.5)
R864=ax.scatter(data_L64["p"],R2_L64, marker="o", color=colors4[4], edgecolor=colors4[0], linewidth = 1,label = "N=64", s = 90)

ax.legend()
ax.set_yscale("log")
ax.set_xlabel("p", fontsize = 20)
ax.set_xlim(4,11)
ax.set_ylim(10e-4,1)

ax.legend(fontsize = 18, frameon = False)
ax.set_yticks([1.1,10e-2,10e-4])
#ax.set_xticks([0,4,8,12,16])
ax.set_yticklabels([r"$10^{0}$",r"$10^{-2}$",r"$10^{-4}$"])
ax.tick_params(labelsize = 18)

# %%
data_Fidelity=pd.read_csv("..\\data\\correlators_Z2\\Fidelity_L32_L64.csv")
results32=data_Fidelity["Fidelity_L32"]
results64=data_Fidelity["Fidelity_L64"]
p_values = data_Fidelity["p"]

# %%
exact_data_8=pd.read_csv("..\\data\\correlators_Z2\\Ising_exact_L8.csv")
fid_L8=exact_data_8["fid"]
h_L8=exact_data_8["h"]

# %%
exact_data_16=pd.read_csv("..\\data\\correlators_Z2\\Ising_exact_L16.csv")
fid_L16=exact_data_16["fid"]
h_L16=exact_data_16["h"]

# %%
fig, ax = plt.subplots(1)
s=0.5
colors = plt.get_cmap("Oranges")(np.linspace(0.1, 1, 5))
colors2 = plt.get_cmap("Greens")(np.linspace(0.1, 1, 5))
ax.plot(4*h_L8, fid_L8, color = colors[1], label = "N=8", linewidth =3,zorder=0)
ax.plot(4*h_L16, fid_L16, color = colors[2], label = "N=16", linewidth = 3,zorder=0)
ax.plot(s*p_values, results32, color = colors[3], linewidth = 3,zorder=0)
ax.plot(s*p_values, results64, color = colors[4], linewidth = 3,zorder=0)


ax.scatter(s*p_values,results32, marker="o", color=colors[3], edgecolor=colors[0], label = "N=32", linewidth = 1, s = 100,zorder = 5)
ax.scatter(s*p_values,results64, marker="o", color=colors[4], edgecolor=colors[0], label = "N=64", linewidth = 1, s = 100,zorder = 5)


ax.legend(fontsize = 18, frameon = False)
ax.set_yticks([0,0.5,1])
ax.set_xticks([0,2,4,6,8])
ax.set_yticklabels(["0","0.5","1"])
ax.tick_params(labelsize = 20)

ax.set_ylabel(r"$F_X(\frac{N}{4},\frac{3N}{4})$", fontsize = 20)

ax.set_xlabel(r"ps", fontsize = 20)

plt.gcf().subplots_adjust(left=0.15)
plt.gcf().subplots_adjust(bottom=0.15)
