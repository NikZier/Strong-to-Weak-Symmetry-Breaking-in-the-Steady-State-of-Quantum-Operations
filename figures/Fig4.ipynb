# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.patches import Ellipse

# %%
data_L8=pd.read_csv(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\DMRG_Potts_results\Potts_DMRG_L8.csv", header = None, skiprows =3)
R2_L8_sig=data_L8[0]
R2_L8_Q=data_L8[1]
ps = data_L8[2]

# %%
data_L16=pd.read_csv(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\DMRG_Potts_results\Potts_DMRG_L16.csv", header = None, skiprows =3)
R2_L16_sig=data_L16[0]
R2_L16_Q=data_L16[1]
ps = data_L16[2]

# %%
data_L32=pd.read_csv(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\DMRG_Potts_results\Potts_DMRG_L32.csv", header = None, skiprows =3)
R2_L32_sig=data_L32[0]
R2_L32_Q=data_L32[1]
ps = data_L32[2]

# %%
data_L64=pd.read_csv(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\DMRG_Potts_results\Potts_DMRG_L64.csv", header = None, skiprows =3)
R2_L64_sig=data_L64[0]
R2_L64_Q=data_L64[1]
ps = data_L64[2]

# %%
colors2 = plt.get_cmap("Greens")(np.linspace(0.1, 1.0, 5))
colors = plt.get_cmap("Blues")(np.linspace(0.1, 1.0, 5))
fig, ax = plt.subplots(1)


ax.plot(ps,R2_L8_sig,color=colors[1],zorder=1, linewidth = 2.5)
L8s=ax.scatter(ps,R2_L8_sig, marker="o", color=colors[1], edgecolor=colors[0], linewidth = 1, label = "L=8", s = 90)

ax.plot(ps,R2_L8_Q,color=colors2[1],zorder=1, linewidth = 2.5)
L8Q=ax.scatter(ps,R2_L8_Q, marker="s", color=colors2[1], edgecolor=colors2[0], linewidth = 1, label = "L=8", s = 90)

ax.plot(ps,R2_L16_sig,color=colors[2],zorder=1, linewidth = 2.5)
L16s=ax.scatter(ps,R2_L16_sig, marker="o", color=colors[2], edgecolor=colors[0], linewidth = 1, label = "L=16", s = 90)

ax.plot(ps,R2_L16_Q,color=colors2[2],zorder=1, linewidth = 2.5)
L16Q=ax.scatter(ps,R2_L16_Q, marker="s", color=colors2[2], edgecolor=colors2[0], linewidth = 1, label = "L=16", s = 90)

ax.plot(ps,R2_L32_sig,color=colors[3],zorder=1, linewidth = 2.5)
L32s=ax.scatter(ps,R2_L32_sig, marker="o", color=colors[3], edgecolor=colors[0], linewidth = 1, label = "L=32", s = 90)


ax.plot(ps,R2_L32_Q,color=colors2[3],zorder=1, linewidth = 2.5)
L32Q=ax.scatter(ps,R2_L32_Q, marker="s", color=colors2[3], edgecolor=colors2[0], linewidth = 1, label = "L=32", s = 90)

ax.plot(ps[3:],R2_L64_sig[3:],color=colors[4],zorder=1, linewidth = 2.5)
L64s=ax.scatter(ps[3:],R2_L64_sig[3:], marker="o", color=colors[4], edgecolor=colors[0], linewidth = 1, label = "L=64", s = 90)

ax.plot(ps[3:],R2_L64_Q[3:],color=colors2[4],zorder=1, linewidth = 2.5)
L64Q=ax.scatter(ps[3:],R2_L64_Q[3:], marker="s", color=colors2[4], edgecolor=colors2[0], linewidth = 1, label = "L=64", s = 90)

legend1 = ax.legend(handles=[L8s,L16s,L32s,L64s], loc="upper right", title=r"$\sigma$-$\sigma$ correlations", frameon = False, fontsize = 12)
ax.add_artist(legend1)

legend1 = ax.legend(handles=[L8Q,L16Q,L32Q,L64Q], loc="center right", title=r"$Q$-$Q$ correlations", frameon = False, fontsize = 12)
ax.add_artist(legend1)


ax.set_xlabel(r"$p$", fontsize = 18)
ax.set_yticks([0,0.25,0.5])
ax.set_xticks([0,4,8,12])
ax.set_yticklabels(["0","0.25","0.5"])
ax.tick_params(labelsize = 16)
plt.gcf().subplots_adjust(left=0.20)
plt.gcf().subplots_adjust(bottom=0.15)
ax.set_ylabel(r"$C^{sw}(\frac{N}{4},\frac{3N}{4})$", fontsize = 18)
fig.savefig(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\figs\Renyi2_MPS_S3_legend.pdf", format = "pdf")

# %%
data_L8=pd.read_csv(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\DMRG_Ising\Ising_DMRG_L8.csv", header = None, skiprows =1)
#data_L8 = data_L8.apply(pd.to_numeric, errors='coerce')
R2_L8=data_L8[0]
R4_L8=data_L8[1]
R6_L8=data_L8[2]
R8_L8=data_L8[3]
ps = data_L8[4]

# %%
data_L16=pd.read_csv(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\DMRG_Ising\Ising_DMRG_L16.csv", header = None, skiprows =1)
data_L16 = data_L16.apply(pd.to_numeric, errors='coerce')
R2_L16=data_L16[0]
R4_L16=data_L16[1]
R6_L16=data_L16[2]
R8_L16=data_L16[3]
ps = data_L16[4]

# %%
data_L32=pd.read_csv(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\DMRG_Ising\Ising_DMRG_L32.csv", header = None, skiprows =1)
data_L32 = data_L32.apply(pd.to_numeric, errors='coerce')
R2_L32=data_L32[0]
R4_L32=data_L32[1]
R6_L32=data_L32[2]
R8_L32=data_L32[3]
ps = data_L32[4]

# %%
data_L64=pd.read_csv(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\DMRG_Ising\Ising_DMRG_L64.csv", header = None, skiprows =1)
data_L64 = data_L64.apply(pd.to_numeric, errors='coerce')
R2_L64=data_L64[0]
R4_L64=data_L64[1]
R6_L64=data_L64[2]
R8_L64=data_L64[3]
ps = data_L64[4]

# %%
data_L64
# Out:
#                0             1             2             3          4
# 0   9.999996e-01  9.999984e-01  9.999965e-01  9.999938e-01   0.010000
# 1   9.971551e-01  9.886208e-01  9.725001e-01  9.533829e-01   0.851579
# 2   9.886084e-01  9.544517e-01  8.990060e-01  8.201148e-01   1.693158
# 3   9.738985e-01  8.958135e-01  7.754087e-01  6.398934e-01   2.534737
# 4   9.521436e-01  8.099414e-01  6.090865e-01  4.102410e-01   3.376316
# 5   9.218017e-01  6.933008e-01  4.170112e-01  2.126137e-01   4.217895
# 6   8.801216e-01  5.428675e-01  2.303603e-01  7.349219e-02   5.059474
# 7   8.216970e-01  3.597109e-01  7.965214e-02  1.311780e-02   5.901053
# 8   7.326470e-01  1.456031e-01  1.036262e-02  1.166522e-03   6.742632
# 9   6.496613e-01  4.182804e-02  1.716184e-03  1.268372e-04   7.200000
# 10  4.884564e-01  5.979525e-03  1.258380e-04  4.236922e-06   7.584211
# 11  1.219747e-01  1.050329e-04  3.798231e-07  1.941087e-09   8.080000
# ...

# %%
colors1 = plt.get_cmap("Greens")(np.linspace(0.1, 1.0, 5))
colors2 = plt.get_cmap("Blues")(np.linspace(0.1, 1.0, 5))
colors3 = plt.get_cmap("Reds")(np.linspace(0.1, 1.0, 5))
colors4 = plt.get_cmap("Oranges")(np.linspace(0.1, 1.0, 5))
fig, ax = plt.subplots(1,figsize=(6,3))
ps=np.linspace(0.01,16,20)
ax.set_title("Rényi-8 correlator", fontsize = 18)
#ax.plot(ps,R2_L8,color=colors1[1],zorder=1, linewidth = 2.5)
#R28=ax.scatter(ps,R2_L8, marker="o", color=colors1[1], edgecolor=colors1[0], linewidth = 1, s = 90)

#ax.plot(ps,R2_L16,color=colors1[2],zorder=1, linewidth = 2.5)
#R216=ax.scatter(ps,R2_L16, marker="o", color=colors1[2], edgecolor=colors1[0], linewidth = 1, s = 90)

#ax.plot(ps,R2_L32,color=colors1[3],zorder=1, linewidth = 2.5)
#R232=ax.scatter(ps,R2_L32, marker="o", color=colors1[3], edgecolor=colors1[0], linewidth = 1, label = "n=2", s = 90)

#ax.plot(ps,R2_L64,color=colors1[4],zorder=1, linewidth = 2.5)
#R264=ax.scatter(ps,R2_L64, marker="o", color=colors1[4], edgecolor=colors1[0], linewidth = 1, label = "n=2", s = 90)


#ax.plot(ps,R4_L8,color=colors2[1],zorder=1, linewidth = 2.5)
#R48=ax.scatter(ps,R4_L8, marker="s", color=colors2[1], edgecolor=colors2[0], linewidth = 1, s = 90)

#ax.plot(ps,R4_L16,color=colors2[2],zorder=1, linewidth = 2.5)
#R416=ax.scatter(ps,R4_L16, marker="s", color=colors2[2], edgecolor=colors2[0], linewidth = 1, s = 90)

#ax.plot(ps,R4_L32,color=colors2[3],zorder=1, linewidth = 2.5)
#R432=ax.scatter(ps,R4_L32, marker="s", color=colors2[3], edgecolor=colors2[0], linewidth = 1, label = "n=4", s = 90)

#ax.plot(ps,R4_L64,color=colors2[4],zorder=1, linewidth = 2.5)
#R464=ax.scatter(ps,R4_L64, marker="s", color=colors2[4], edgecolor=colors2[0], linewidth = 1, label = "n=4", s = 90)


#ax.plot(ps,R6_L8,color=colors3[1],zorder=1, linewidth = 2.5)
#R68=ax.scatter(ps,R6_L8, marker="d", color=colors3[1], edgecolor=colors3[0], linewidth = 1, s = 90)

#ax.plot(ps,R6_L16,color=colors3[2],zorder=1, linewidth = 2.5)
#R616=ax.scatter(ps,R6_L16, marker="d", color=colors3[2], edgecolor=colors3[0], linewidth = 1, s = 90)

#ax.plot(ps,R6_L32,color=colors3[3],zorder=1, linewidth = 2.5)
#R632=ax.scatter(ps,R6_L32, marker="d", color=colors3[3], edgecolor=colors3[0], linewidth = 1, label = "n=6", s = 90)

#ax.plot(ps,R6_L64,color=colors3[4],zorder=1, linewidth = 2.5)
#R664=ax.scatter(ps,R6_L64, marker="d", color=colors3[4], edgecolor=colors3[0], linewidth = 1, label = "n=6", s = 90)



ax.plot(ps,R8_L8,color=colors4[1],zorder=1, linewidth = 2.5)
R88=ax.scatter(ps,R8_L8, marker="o", color=colors4[1], edgecolor=colors4[0],label = "N=8", linewidth = 1, s = 90)

ax.plot(ps,R8_L16,color=colors4[2],zorder=1, linewidth = 2.5)
R816=ax.scatter(ps,R8_L16, marker="o", color=colors4[2], edgecolor=colors4[0],label = "N=16", linewidth = 1, s = 90)

ax.plot(data_L32[4],R8_L32,color=colors4[3],zorder=1, linewidth = 2.5)
R832=ax.scatter(data_L32[4],R8_L32, marker="o", color=colors4[3], edgecolor=colors4[0], linewidth = 1,label = "N=32", s = 90)

ax.plot(data_L32[4],R8_L64,color=colors4[4],zorder=1, linewidth = 2.5)
R864=ax.scatter(data_L32[4],R8_L64, marker="o", color=colors4[4], edgecolor=colors4[0], linewidth = 1,label = "N=64", s = 90)

ax.legend()
ax.set_yscale("log")
ax.set_xlabel("p", fontsize = 20)
ax.set_xlim(4,11)
ax.set_ylim(10e-10,1)

ax.legend(fontsize = 18, frameon = False)
ax.set_yticks([1,10e-5,10e-10])
#ax.set_xticks([0,4,8,12,16])
ax.set_yticklabels([r"$10^{0}$",r"$10^{-5}$",r"$10^{-10}$"])
ax.tick_params(labelsize = 18)


fig.savefig(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\figs\R8_postselection.pdf", format = "pdf")

# %%
colors4 = plt.get_cmap("Oranges")(np.linspace(0.1, 1.0, 5))
fig, ax = plt.subplots(1,figsize=(6,3))
ps=np.linspace(0.01,16,20)
ax.set_title("Rényi-6 correlator", fontsize = 18)

ax.plot(ps,R6_L8,color=colors4[1],zorder=1, linewidth = 2.5)
R88=ax.scatter(ps,R6_L8, marker="o", color=colors4[1], edgecolor=colors4[0],label = "N=8", linewidth = 1, s = 90)

ax.plot(ps,R6_L16,color=colors4[2],zorder=1, linewidth = 2.5)
R816=ax.scatter(ps,R6_L16, marker="o", color=colors4[2], edgecolor=colors4[0],label = "N=16", linewidth = 1, s = 90)

ax.plot(data_L32[4],R6_L32,color=colors4[3],zorder=1, linewidth = 2.5)
R832=ax.scatter(data_L32[4],R6_L32, marker="o", color=colors4[3], edgecolor=colors4[0], linewidth = 1,label = "N=32", s = 90)

ax.plot(data_L32[4],R6_L64,color=colors4[4],zorder=1, linewidth = 2.5)
R864=ax.scatter(data_L32[4],R6_L64, marker="o", color=colors4[4], edgecolor=colors4[0], linewidth = 1,label = "N=64", s = 90)

ax.legend()
ax.set_yscale("log")
ax.set_xlabel("p", fontsize = 20)
ax.set_xlim(4,11)
ax.set_ylim(10e-10,1)

ax.legend(fontsize = 18, frameon = False)
ax.set_yticks([1,10e-5,10e-10])
#ax.set_xticks([0,4,8,12,16])
ax.set_yticklabels([r"$10^{0}$",r"$10^{-5}$",r"$10^{-10}$"])
ax.tick_params(labelsize = 18)


fig.savefig(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\figs\R6_postselection.pdf", format = "pdf")

# %%
colors4 = plt.get_cmap("Oranges")(np.linspace(0.1, 1.0, 5))
fig, ax = plt.subplots(1,figsize=(6,3))
ps=np.linspace(0.01,16,20)
ax.set_title("Rényi-4 correlator", fontsize = 18)

ax.plot(ps,R4_L8,color=colors4[1],zorder=1, linewidth = 2.5)
R88=ax.scatter(ps,R4_L8, marker="o", color=colors4[1], edgecolor=colors4[0],label = "N=8", linewidth = 1, s = 90)

ax.plot(ps,R4_L16,color=colors4[2],zorder=1, linewidth = 2.5)
R816=ax.scatter(ps,R4_L16, marker="o", color=colors4[2], edgecolor=colors4[0],label = "N=16", linewidth = 1, s = 90)

ax.plot(data_L32[4],R4_L32,color=colors4[3],zorder=1, linewidth = 2.5)
R832=ax.scatter(data_L32[4],R4_L32, marker="o", color=colors4[3], edgecolor=colors4[0], linewidth = 1,label = "N=32", s = 90)

ax.plot(data_L32[4],R4_L64,color=colors4[4],zorder=1, linewidth = 2.5)
R864=ax.scatter(data_L32[4],R4_L64, marker="o", color=colors4[4], edgecolor=colors4[0], linewidth = 1,label = "N=64", s = 90)

ax.legend()
ax.set_yscale("log")
ax.set_xlabel("p", fontsize = 20)
ax.set_xlim(4,11)
ax.set_ylim(10e-4,1)

ax.legend(fontsize = 18, frameon = False)
ax.set_yticks([1.1,10e-2,10e-4])
#ax.set_xticks([0,4,8,12,16])
ax.set_yticklabels([r"$10^{0}$",r"$10^{-2}$",r"$10^{-4}$"])
ax.tick_params(labelsize = 18)


fig.savefig(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\figs\R4_postselection.pdf", format = "pdf")

# %%
colors4 = plt.get_cmap("Oranges")(np.linspace(0.1, 1.0, 5))
fig, ax = plt.subplots(1,figsize=(6,3))
ps=np.linspace(0.01,16,20)
ax.set_title("Rényi-2 correlator", fontsize = 18)

ax.plot(ps,R2_L8,color=colors4[1],zorder=1, linewidth = 2.5)
R88=ax.scatter(ps,R2_L8, marker="o", color=colors4[1], edgecolor=colors4[0],label = "N=8", linewidth = 1, s = 90)

ax.plot(ps,R2_L16,color=colors4[2],zorder=1, linewidth = 2.5)
R816=ax.scatter(ps,R2_L16, marker="o", color=colors4[2], edgecolor=colors4[0],label = "N=16", linewidth = 1, s = 90)

ax.plot(data_L32[4],R2_L32,color=colors4[3],zorder=1, linewidth = 2.5)
R832=ax.scatter(data_L32[4],R2_L32, marker="o", color=colors4[3], edgecolor=colors4[0], linewidth = 1,label = "N=32", s = 90)

ax.plot(data_L32[4],R2_L64,color=colors4[4],zorder=1, linewidth = 2.5)
R864=ax.scatter(data_L32[4],R2_L64, marker="o", color=colors4[4], edgecolor=colors4[0], linewidth = 1,label = "N=64", s = 90)

ax.legend()
ax.set_yscale("log")
ax.set_xlabel("p", fontsize = 20)
ax.set_xlim(4,11)
ax.set_ylim(10e-4,1)

ax.legend(fontsize = 18, frameon = False)
ax.set_yticks([1.1,10e-2,10e-4])
#ax.set_xticks([0,4,8,12,16])
ax.set_yticklabels([r"$10^{0}$",r"$10^{-2}$",r"$10^{-4}$"])
ax.tick_params(labelsize = 18)


fig.savefig(r"C:\Users\nzier\Documents\QuantumActiveMatter\QuantumCircuits\figs\R2_postselection.pdf", format = "pdf")

# %%
fig, ax=plt.subplots(ncols=2, figsize=(15,5))
ms=[1/2,2,4,6,8]
ax[0].scatter(ms,[0.8380108474751926,R2_L8[12],R4_L8[12],R6_L8[12],R8_L8[12]],label = "L=8")
ax[0].plot(ms,[0.8380108474751926,R2_L8[12],R4_L8[12],R6_L8[12],R8_L8[12]])

ax[0].scatter(ms,[0.7793880098269351,R2_L16[12],R4_L16[12],R6_L16[12],R8_L16[12]],label = "L=16")
ax[0].plot(ms,[0.7793880098269351,R2_L16[12],R4_L16[12],R6_L16[12],R8_L16[12]])

ax[0].scatter(ms[1:],[R2_L32[12],R4_L32[12],R6_L32[12],R8_L32[12]],label = "L=32")
ax[0].plot(ms[1:],[R2_L32[12],R4_L32[12],R6_L32[12],R8_L32[12]])

ax[0].annotate(
    'Fidelity',        # Text
    xy=(1/2, 0.8380108474751926),      # Point to annotate
    xytext=(1/2 + 0.5, 0.8380108474751926 - 0.8),  # Position of the text
    arrowprops=dict(facecolor='black', arrowstyle='->'),
    ha='center'
)
ax[0].legend()
ax[0].set_yscale("log")
ax[0].set_xlabel("m",fontsize =18)

ax[1].scatter(ms,[0.8380108474751926,R2_L8[12],R4_L8[12],R6_L8[12],R8_L8[12]],label = "L=8")
ax[1].plot(ms,[0.8380108474751926,R2_L8[12],R4_L8[12],R6_L8[12],R8_L8[12]])

ax[1].scatter(ms,[0.7793880098269351,R2_L16[12],R4_L16[12],R6_L16[12],R8_L16[12]],label = "L=16")
ax[1].plot(ms,[0.7793880098269351,R2_L16[12],R4_L16[12],R6_L16[12],R8_L16[12]])

ax[1].scatter(ms[1:],[R2_L32[12],R4_L32[12],R6_L32[12],R8_L32[12]],label = "L=32")
ax[1].plot(ms[1:],[R2_L32[12],R4_L32[12],R6_L32[12],R8_L32[12]])

ax[1].annotate(
    'Fidelity',        # Text
    xy=(1/2, 0.8380108474751926),      # Point to annotate
    xytext=(1/2 + 1, 0.8380108474751926 - 0.1),  # Position of the text
    arrowprops=dict(facecolor='black', arrowstyle='->'),
    ha='center'
)
ax[1].legend()
ax[1].set_xlabel("m",fontsize =18)

ellipse = Ellipse(
    (1/2, 0.8),  # (x, y) center of ellipse
    width=0.2,             # Horizontal diameter
    height=0.2,            # Vertical diameter
    edgecolor='black',
    facecolor='none',      # Transparent fill
    linewidth=1
)

# Add the ellipse to the axes
ax[1].add_patch(ellipse)
fig.suptitle(r"Rényi-m correlator at $p\approx 10$ (close to the transition, strongly symmetric/ paramagnetic side)", fontsize=14)
# Out:
# Text(0.5, 0.98, 'Rényi-m correlator at $p\\approx 10$ (close to the transition, strongly symmetric/ paramagnetic side)')
