# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import time
import csv
import pandas as pd
np.set_printoptions(precision=5, suppress=True, linewidth=100)
plt.rcParams['figure.dpi'] = 150
import tenpy
import tenpy.linalg.np_conserved as npc
from tenpy.algorithms import tebd
from tenpy.networks.mps import MPS
from tenpy.models.model import CouplingMPOModel
from tenpy.models.model import NearestNeighborModel
from tenpy.networks import site
import matplotlib.pyplot as plt
tenpy.tools.misc.setup_logging(to_stdout="INFO")

from tenpy.models.lattice import Square
from numpy.linalg import svd
from tenpy.algorithms import dmrg
from tenpy.linalg.truncation import svd_theta
from tenpy.linalg.sparse import FlatLinearOperator
from tenpy.tools.math import speigs
import copy

# %% [markdown]
# ### Average effective Hamiltonian in the doubled Hilbert space of a Z2 symmetric Brownian circuit

# %%
class Ising_2copy(CouplingMPOModel):
    """Average time evolution in doubled Hilbert space of random TFI"""

    default_lattice = "Chain"
    force_default_lattice = True

    def init_sites(self, model_params):
        X= np.array([[0,1],[1,0]])
        spin1 = site.SpinHalfSite(conserve="parity")
        spin2 = site.SpinHalfSite(conserve="parity")
        #spin1.add_op('Sx',1/2*X)
        #spin2.add_op('Sx',1/2*X)
        sites = [spin1, spin2]
        
        site.set_common_charges(sites, new_charges='independent')
        return [spin1, spin2], ['sf', 'sb']  # return species names as well!
        # this causes `init_lattice` to initialize a `MultiSpeciesLattice`
        
    def init_terms(self, model_params):
        J = model_params.get('J', 1.)
        U = model_params.get('U', 1.)
        s = model_params.get('s', 0.5)
        p = model_params.get('p', 0.1)
        # onsite f-b interaction
        self.add_coupling(-2*U, 0, 'Sigmaz', 1, 'Sigmaz', [0])
        # magnetic field from postselection
        self.add_onsite(-p*s/4,0,'Sigmaz')
        self.add_onsite(-p*s/4,1,'Sigmaz')
        # f-b hopping term
        self.add_multi_coupling(-2*J,[('Sigmax',[0],0),('Sigmax',[1],0),('Sigmax',[0],1),('Sigmax',[1],1)])

# %% [markdown]
# ### Run a DMRG simulation to find the groundstate

# %%
product_state = [('up','up')]
print('product_state = ')
print(product_state)
print()
initial_time=time.time()
Ls=[16]
Np=20
cor=np.zeros((len(Ls),Np))
ps =np.linspace(0.01,16,Np)
states=[]
for i,L in enumerate(Ls):
    print("L=",L)
    print()
    for j,prob in enumerate(ps):
        print("p=",prob)
        M=Ising_2copy({'L':L,'p':prob,'s':0.5})
        psi0 = MPS.from_lat_product_state(M.lat, product_state)
        eng = tenpy.algorithms.dmrg.SingleSiteDMRGEngine(psi0, M, {'mixer_params': {"amplitude": 1e-5},
                                                                        'trunc_params': {'chi_max': 100, 'svd_min':1e-7}, 'max_sweeps':30,'max_E_err':1.0e-12})
        E, psi = eng.run()
        states.append(psi.copy())
        cor[i,j]=float(psi.expectation_value_term([('Sigmax',int((L/4-1)*2)),('Sigmax',int((L/4-1)*2+1)),('Sigmax',int(L-L/4-1)*2),('Sigmax',int(L-L/4-1)*2+1)]))
    print()
    print("---------------------------------------------------")
    print(time.time()-initial_time)
# Out:
# product_state =
# [('up', 'up')]
#
# L= 16
#
# p= 0.01
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(0.01)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-62.0000140625013358, max S=1.0394045397033917, age=32, norm_err=1.0e+00
# Current memory usage 274.0MB, wall time: 0.7s
# Delta E = nan, Delta S = 7.7860e-01 (per sweep)
# max trunc_err = 9.5397e-47, max E_trunc = 5.4742e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-62.0000140625017195, max S=1.3862941660344383, age=32, norm_err=9.5e-05
# Current memory usage 274.0MB, wall time: 0.6s
# Delta E = -3.8369e-13, Delta S = 2.2758e-01 (per sweep)
# max trunc_err = 9.3019e-22, max E_trunc = 2.7899e-03
# chi: [2, 2, 4, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-62.0000140625016343, max S=1.3862941659235810, age=32, norm_err=4.7e-05
# Current memory usage 274.0MB, wall time: 0.7s
# Delta E = 8.5265e-14, Delta S = -1.0025e-10 (per sweep)
# max trunc_err = 9.2905e-22, max E_trunc = 1.3950e-03
# chi: [2, 2, 4, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=4.999999999999999e-16
# INFO    : checkpoint after sweep 4
# energy=-62.0000140625006253, max S=1.3862941658073780, age=32, norm_err=2.0e-14
# Current memory usage 274.0MB, wall time: 0.5s
# Delta E = 1.0090e-12, Delta S = -1.0523e-10 (per sweep)
# max trunc_err = 9.5367e-15, max E_trunc = 9.2371e-14
# chi: [2, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-62.0000140625004903, max S=1.3862941658073780, age=32, norm_err=2.8e-14
# Current memory usage 274.0MB, wall time: 0.5s
# Delta E = 1.3500e-13, Delta S = -2.2204e-16 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 3.5527e-14
# chi: [2, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 5 sweeps, max chi=4
# p= 0.8515789473684211
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(0.8515789473684211)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-62.1020454375829800, max S=0.9927078847892201, age=32, norm_err=9.9e-01
# Current memory usage 274.0MB, wall time: 0.6s
# Delta E = nan, Delta S = 7.5170e-01 (per sweep)
# max trunc_err = 1.7678e-38, max E_trunc = 5.4936e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=4.999999999999999e-16
# INFO    : checkpoint after sweep 2
# energy=-62.1020598767799683, max S=1.3848744440246290, age=32, norm_err=9.5e-05
# Current memory usage 274.0MB, wall time: 0.6s
# Delta E = -1.4439e-05, Delta S = 2.5274e-01 (per sweep)
# max trunc_err = 7.0112e-15, max E_trunc = 2.7945e-03
# chi: [2, 2, 4, 4, 8, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-62.1020598767798546, max S=1.3848738923535344, age=32, norm_err=4.7e-05
# Current memory usage 274.0MB, wall time: 0.7s
# Delta E = 1.1369e-13, Delta S = -4.6915e-07 (per sweep)
# max trunc_err = 3.5056e-15, max E_trunc = 1.3973e-03
# chi: [2, 2, 4, 4, 8, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-62.1020598767798333, max S=1.3848733061174701, age=32, norm_err=4.3e-13
# Current memory usage 274.0MB, wall time: 0.5s
# Delta E = 2.1316e-14, Delta S = -4.8696e-07 (per sweep)
# max trunc_err = 4.0677e-16, max E_trunc = 4.2633e-14
# chi: [2, 2, 4, 4, 8, 6, 8, 6, 8, 6, 8, 6, 8, 6, 8, 6, 8, 6, 8, 6, 8, 6, 8, 6, 8, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 4 sweeps, max chi=8
# p= 1.6931578947368422
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(1.6931578947368422)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-62.4041117965026970, max S=0.9363005059006713, age=32, norm_err=9.6e-01
# Current memory usage 274.0MB, wall time: 0.7s
# Delta E = nan, Delta S = 7.1581e-01 (per sweep)
# max trunc_err = 2.4249e-37, max E_trunc = 5.5320e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=4.999999999999999e-16
# INFO    : checkpoint after sweep 2
# energy=-62.4044112370009927, max S=1.3806261241505318, age=32, norm_err=9.5e-05
# Current memory usage 274.0MB, wall time: 0.6s
# Delta E = -2.9944e-04, Delta S = 2.8336e-01 (per sweep)
# max trunc_err = 5.3526e-15, max E_trunc = 2.8081e-03
# chi: [2, 2, 4, 4, 8, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-62.4044112370008435, max S=1.3806241379066138, age=32, norm_err=4.8e-05
# Current memory usage 274.0MB, wall time: 0.6s
# Delta E = 1.4921e-13, Delta S = -1.6406e-06 (per sweep)
# max trunc_err = 2.6765e-15, max E_trunc = 1.4041e-03
# chi: [2, 2, 4, 4, 8, 6, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-62.4044112370009501, max S=1.3806220849625823, age=32, norm_err=4.3e-14
# Current memory usage 274.0MB, wall time: 0.5s
# Delta E = -1.0658e-13, Delta S = -1.6822e-06 (per sweep)
# max trunc_err = 5.1194e-16, max E_trunc = 6.3949e-14
# chi: [2, 2, 4, 4, 8, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 4 sweeps, max chi=12
# p= 2.534736842105263
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(2.534736842105263)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-62.9080347736688807, max S=0.8747972897694615, age=32, norm_err=9.1e-01
# Current memory usage 274.0MB, wall time: 0.7s
# Delta E = nan, Delta S = 6.7250e-01 (per sweep)
# max trunc_err = 3.1891e-37, max E_trunc = 5.5890e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=4.999999999999999e-16
# INFO    : checkpoint after sweep 2
# energy=-62.9099807543092027, max S=1.3733852446096337, age=32, norm_err=9.6e-05
# Current memory usage 274.0MB, wall time: 0.7s
# Delta E = -1.9460e-03, Delta S = 3.1752e-01 (per sweep)
# max trunc_err = 8.8525e-15, max E_trunc = 2.8308e-03
# chi: [2, 2, 4, 4, 8, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 12, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-62.9099807543092240, max S=1.3733812061878556, age=32, norm_err=4.8e-05
# Current memory usage 274.0MB, wall time: 0.9s
# Delta E = -2.1316e-14, Delta S = -3.3388e-06 (per sweep)
# max trunc_err = 1.2294e-14, max E_trunc = 1.4154e-03
# chi: [2, 2, 4, 4, 8, 8, 12, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 12, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 1.25e-06
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-62.9099807543092240, max S=1.3733771111470874, age=32, norm_err=6.9e-13
# Current memory usage 274.0MB, wall time: 0.6s
# Delta E = 0.0000e+00, Delta S = -3.3957e-06 (per sweep)
# max trunc_err = 8.4264e-16, max E_trunc = 5.6843e-14
# chi: [2, 2, 4, 4, 8, 8, 12, 10, 12, 10, 12, 10, 12, 10, 12, 10, 12, 10, 12, 10, 12, 10, 12, 10, 12, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 4 sweeps, max chi=12
# p= 3.376315789473684
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(3.376315789473684)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-63.6163288009625063, max S=0.8096574885288417, age=32, norm_err=8.3e-01
# Current memory usage 274.0MB, wall time: 0.7s
# Delta E = nan, Delta S = 6.2260e-01 (per sweep)
# max trunc_err = 1.9391e-37, max E_trunc = 5.6643e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=np.float64(1.3573224112470933e-15)
# INFO    : checkpoint after sweep 2
# energy=-63.6239389272452840, max S=1.3628687659665892, age=32, norm_err=9.6e-05
# Current memory usage 274.0MB, wall time: 0.8s
# Delta E = -7.6101e-03, Delta S = 3.5357e-01 (per sweep)
# max trunc_err = 2.7146e-14, max E_trunc = 2.8629e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-63.6239389272472238, max S=1.3628622726559607, age=32, norm_err=4.8e-05
# Current memory usage 274.0MB, wall time: 0.8s
# Delta E = -1.9398e-12, Delta S = -5.4401e-06 (per sweep)
# max trunc_err = 3.1659e-14, max E_trunc = 1.4315e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 10, 20, 10, 20, 10, 20, 12, 20, 12, 20, 12, 20, 10, 20, 10, 20, 10, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-63.6239389272471740, max S=1.3628589948753167, age=32, norm_err=2.4e-05
# Current memory usage 274.0MB, wall time: 0.9s
# Delta E = 4.9738e-14, Delta S = -2.7550e-06 (per sweep)
# max trunc_err = 2.8436e-14, max E_trunc = 7.1576e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 10, 17, 10, 20, 10, 20, 12, 20, 12, 20, 12, 20, 10, 20, 10, 17, 10, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 6.25e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-63.6239389272463995, max S=1.3628557013574265, age=32, norm_err=7.4e-12
# Current memory usage 274.1MB, wall time: 0.6s
# Delta E = 7.7449e-13, Delta S = -2.7896e-06 (per sweep)
# max trunc_err = 3.5804e-14, max E_trunc = 4.2633e-13
# chi: [2, 2, 4, 4, 8, 8, 12, 10, 12, 10, 12, 10, 16, 10, 16, 10, 16, 10, 16, 10, 12, 10, 12, 10, 12, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 5 sweeps, max chi=16
# p= 4.217894736842105
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(4.217894736842105)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-64.5327606906560476, max S=0.7409365562968906, age=32, norm_err=7.3e-01
# Current memory usage 274.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 5.6674e-01 (per sweep)
# max trunc_err = 3.2687e-36, max E_trunc = 5.7580e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=4.999999999999999e-16
# INFO    : checkpoint after sweep 2
# energy=-64.5543618574198774, max S=1.3485468978960347, age=32, norm_err=9.8e-05
# Current memory usage 274.1MB, wall time: 0.7s
# Delta E = -2.1601e-02, Delta S = 3.8932e-01 (per sweep)
# max trunc_err = 5.8566e-15, max E_trunc = 2.9048e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-64.5543618574599805, max S=1.3485379222928027, age=32, norm_err=4.9e-05
# Current memory usage 274.1MB, wall time: 0.7s
# Delta E = -4.0103e-11, Delta S = -7.6445e-06 (per sweep)
# max trunc_err = 3.5803e-14, max E_trunc = 1.4524e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 10, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-64.5543618574601510, max S=1.3485332220494193, age=32, norm_err=2.4e-05
# Current memory usage 274.1MB, wall time: 0.7s
# Delta E = -1.7053e-13, Delta S = -4.0239e-06 (per sweep)
# max trunc_err = 3.4471e-14, max E_trunc = 7.2623e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 10, 20, 12, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 10, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 6.25e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-64.5543618574591704, max S=1.3485285031813898, age=32, norm_err=5.8e-11
# Current memory usage 274.1MB, wall time: 0.5s
# Delta E = 9.8055e-13, Delta S = -4.0737e-06 (per sweep)
# max trunc_err = 2.9851e-14, max E_trunc = 4.8317e-13
# chi: [2, 2, 4, 4, 8, 8, 12, 10, 20, 10, 20, 10, 20, 12, 20, 12, 20, 12, 20, 10, 20, 10, 20, 10, 12, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 5 sweeps, max chi=20
# p= 5.059473684210526
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(5.059473684210526)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-65.6677922505490415, max S=0.6679335811734904, age=32, norm_err=6.0e-01
# Current memory usage 274.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 5.0576e-01 (per sweep)
# max trunc_err = 3.9195e-35, max E_trunc = 5.8710e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=np.float64(6.065346220778448e-16)
# INFO    : checkpoint after sweep 2
# energy=-65.7139310612954120, max S=1.3281041716315263, age=32, norm_err=1.0e-04
# Current memory usage 274.1MB, wall time: 0.7s
# Delta E = -4.6139e-02, Delta S = 4.2020e-01 (per sweep)
# max trunc_err = 1.2131e-14, max E_trunc = 2.9570e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-65.7139310617628922, max S=1.3280956312272965, age=32, norm_err=5.0e-05
# Current memory usage 274.1MB, wall time: 0.7s
# Delta E = -4.6748e-10, Delta S = -7.3270e-06 (per sweep)
# max trunc_err = 2.5189e-14, max E_trunc = 1.4785e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 20, 14, 24, 14, 28, 14, 28, 14, 28, 14, 28, 14, 24, 14, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-65.7139310617628638, max S=1.3280893316094606, age=32, norm_err=2.5e-05
# Current memory usage 274.1MB, wall time: 0.6s
# Delta E = 2.8422e-14, Delta S = -5.4978e-06 (per sweep)
# max trunc_err = 2.9665e-14, max E_trunc = 7.3927e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 20, 14, 24, 14, 28, 14, 28, 14, 28, 14, 28, 14, 24, 14, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 6.25e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-65.7139310617632759, max S=1.3280830104639660, age=32, norm_err=7.6e-12
# Current memory usage 274.1MB, wall time: 0.5s
# Delta E = -4.1211e-13, Delta S = -5.5640e-06 (per sweep)
# max trunc_err = 8.2192e-15, max E_trunc = 1.2790e-13
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 20, 12, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 12, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 5 sweeps, max chi=20
# p= 5.901052631578947
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(5.901052631578947)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-67.0581465021296594, max S=0.5901398849385358, age=32, norm_err=4.5e-01
# Current memory usage 274.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 4.4180e-01 (per sweep)
# max trunc_err = 1.7829e-35, max E_trunc = 6.0064e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=np.float64(5.308934816373029e-16)
# INFO    : checkpoint after sweep 2
# energy=-67.1257602662112163, max S=1.2859011870931125, age=32, norm_err=1.5e-04
# Current memory usage 274.1MB, wall time: 0.8s
# Delta E = -6.7614e-02, Delta S = 4.3198e-01 (per sweep)
# max trunc_err = 1.0618e-14, max E_trunc = 3.0205e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-67.1257602687844326, max S=1.2859207888385842, age=32, norm_err=5.1e-05
# Current memory usage 274.1MB, wall time: 0.7s
# Delta E = -2.5732e-09, Delta S = 1.7628e-05 (per sweep)
# max trunc_err = 1.7998e-14, max E_trunc = 1.5103e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 24, 14, 28, 14, 28, 14, 28, 14, 28, 15, 28, 14, 28, 14, 24, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-67.1257602687842052, max S=1.2859126492029525, age=32, norm_err=2.6e-05
# Current memory usage 274.1MB, wall time: 0.6s
# Delta E = 2.2737e-13, Delta S = -7.2256e-06 (per sweep)
# max trunc_err = 1.8150e-14, max E_trunc = 7.5516e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 23, 14, 28, 14, 28, 14, 28, 14, 28, 14, 28, 14, 28, 14, 23, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 6.25e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-67.1257602687824857, max S=1.2859044850500807, age=32, norm_err=2.2e-11
# Current memory usage 274.1MB, wall time: 0.5s
# Delta E = 1.7195e-12, Delta S = -7.3063e-06 (per sweep)
# max trunc_err = 3.9213e-14, max E_trunc = 6.3949e-13
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-67.1257602687825710, max S=1.2859044850375279, age=32, norm_err=6.1e-13
# Current memory usage 274.1MB, wall time: 0.5s
# Delta E = -8.5265e-14, Delta S = -4.4993e-12 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 5.6843e-14
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 6 sweeps, max chi=20
# p= 6.7426315789473685
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(6.7426315789473685)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-68.7801970119417092, max S=0.5120083537647602, age=32, norm_err=3.1e-01
# Current memory usage 274.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 3.8027e-01 (per sweep)
# max trunc_err = 2.0022e-35, max E_trunc = 6.1700e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-68.8362415885376890, max S=1.1578642291377013, age=32, norm_err=2.9e-04
# Current memory usage 274.1MB, wall time: 0.8s
# Delta E = -5.6045e-02, Delta S = 3.8653e-01 (per sweep)
# max trunc_err = 1.1719e-14, max E_trunc = 3.0975e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-68.8362415952503710, max S=1.1580170609778579, age=32, norm_err=5.5e-05
# Current memory usage 274.1MB, wall time: 0.7s
# Delta E = -6.7127e-09, Delta S = 1.2783e-04 (per sweep)
# max trunc_err = 2.0173e-14, max E_trunc = 1.5488e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 24, 14, 28, 15, 28, 17, 28, 17, 28, 17, 28, 15, 28, 14, 24, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-68.8362415952505131, max S=1.1580066112816221, age=32, norm_err=2.7e-05
# Current memory usage 274.1MB, wall time: 0.7s
# Delta E = -1.4211e-13, Delta S = -9.3004e-06 (per sweep)
# max trunc_err = 2.1327e-14, max E_trunc = 7.7440e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 24, 14, 28, 15, 28, 17, 28, 16, 28, 16, 28, 15, 28, 14, 24, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 6.25e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-68.8362415952483673, max S=1.1579961310377291, age=32, norm_err=3.5e-11
# Current memory usage 274.2MB, wall time: 0.5s
# Delta E = 2.1458e-12, Delta S = -9.3870e-06 (per sweep)
# max trunc_err = 1.9658e-14, max E_trunc = 3.8369e-13
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 20, 14, 20, 14, 23, 15, 24, 15, 24, 15, 23, 14, 20, 14, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-68.8362415952483531, max S=1.1579961310236997, age=32, norm_err=3.0e-12
# Current memory usage 274.2MB, wall time: 0.5s
# Delta E = 1.4211e-14, Delta S = -5.9516e-12 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-14
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 20, 14, 20, 14, 23, 15, 24, 15, 24, 15, 23, 14, 20, 14, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 6 sweeps, max chi=24
# p= 7.58421052631579
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(7.58421052631579)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-70.8684380839888775, max S=0.4430213832305215, age=32, norm_err=2.0e-01
# Current memory usage 274.2MB, wall time: 0.6s
# Delta E = nan, Delta S = 3.2734e-01 (per sweep)
# max trunc_err = 2.5028e-35, max E_trunc = 6.3640e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-70.8945877140607479, max S=0.9082992644347671, age=32, norm_err=2.4e-04
# Current memory usage 274.2MB, wall time: 0.8s
# Delta E = -2.6150e-02, Delta S = 2.7513e-01 (per sweep)
# max trunc_err = 1.1455e-14, max E_trunc = 3.1901e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-70.8945877223763290, max S=0.9085053842770472, age=32, norm_err=5.9e-05
# Current memory usage 274.2MB, wall time: 0.8s
# Delta E = -8.3156e-09, Delta S = 1.5662e-04 (per sweep)
# max trunc_err = 2.0643e-14, max E_trunc = 1.5951e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 24, 14, 28, 15, 28, 16, 28, 16, 28, 16, 28, 15, 28, 14, 24, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-70.8945877223763148, max S=0.9084922190963122, age=32, norm_err=3.0e-05
# Current memory usage 274.2MB, wall time: 0.6s
# Delta E = 1.4211e-14, Delta S = -1.1518e-05 (per sweep)
# max trunc_err = 1.7652e-14, max E_trunc = 7.9756e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 23, 14, 28, 15, 28, 16, 28, 16, 28, 16, 28, 15, 28, 14, 23, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-70.8945877223762295, max S=0.9084856230096982, age=32, norm_err=1.5e-05
# Current memory usage 274.2MB, wall time: 0.6s
# Delta E = 8.5265e-14, Delta S = -5.7799e-06 (per sweep)
# max trunc_err = 2.0290e-14, max E_trunc = 3.9878e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 22, 14, 27, 15, 28, 15, 28, 16, 28, 16, 28, 14, 27, 14, 22, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 3.125e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-70.8945877223750784, max S=0.9084790129182642, age=32, norm_err=2.9e-11
# Current memory usage 274.2MB, wall time: 0.5s
# Delta E = 1.1511e-12, Delta S = -5.8171e-06 (per sweep)
# max trunc_err = 2.1135e-14, max E_trunc = 4.4054e-13
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 20, 14, 20, 15, 23, 15, 24, 15, 24, 15, 23, 14, 20, 14, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 7
# energy=-70.8945877223751495, max S=0.9084790129083007, age=32, norm_err=1.3e-12
# Current memory usage 274.2MB, wall time: 0.5s
# Delta E = -7.1054e-14, Delta S = -5.2145e-12 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 5.6843e-14
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 20, 14, 20, 15, 23, 15, 24, 15, 24, 15, 23, 14, 20, 14, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 7 sweeps, max chi=24
# p= 8.42578947368421
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(8.42578947368421)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-73.2564476736001069, max S=0.3864719229618302, age=32, norm_err=1.4e-01
# Current memory usage 274.2MB, wall time: 0.6s
# Delta E = nan, Delta S = 2.8437e-01 (per sweep)
# max trunc_err = 2.0226e-35, max E_trunc = 6.5827e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 2
# energy=-73.2660668228306946, max S=0.6796339969900097, age=32, norm_err=1.5e-04
# Current memory usage 274.2MB, wall time: 0.7s
# Delta E = -9.6191e-03, Delta S = 1.7712e-01 (per sweep)
# max trunc_err = 1.5153e-14, max E_trunc = 3.2968e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-73.2660668283782712, max S=0.6797115477101128, age=32, norm_err=6.3e-05
# Current memory usage 274.2MB, wall time: 0.7s
# Delta E = -5.5476e-09, Delta S = 5.1397e-05 (per sweep)
# max trunc_err = 2.2636e-14, max E_trunc = 1.6484e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 22, 14, 25, 14, 28, 15, 28, 16, 28, 15, 28, 14, 26, 14, 22, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-73.2660668283782144, max S=0.6796959947626943, age=32, norm_err=3.1e-05
# Current memory usage 274.2MB, wall time: 0.6s
# Delta E = 5.6843e-14, Delta S = -1.3416e-05 (per sweep)
# max trunc_err = 1.9447e-14, max E_trunc = 8.2423e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 21, 14, 25, 14, 28, 14, 28, 15, 28, 14, 28, 14, 26, 14, 21, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-73.2660668283781149, max S=0.6796882018181617, age=32, norm_err=1.6e-05
# Current memory usage 274.2MB, wall time: 0.6s
# Delta E = 9.9476e-14, Delta S = -6.7266e-06 (per sweep)
# max trunc_err = 2.1095e-14, max E_trunc = 4.1212e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 12, 20, 14, 24, 14, 27, 14, 28, 15, 28, 14, 27, 14, 24, 14, 20, 12, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 3.125e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-73.2660668283772054, max S=0.6796803905760397, age=32, norm_err=2.8e-11
# Current memory usage 274.2MB, wall time: 0.5s
# Delta E = 9.0949e-13, Delta S = -6.7580e-06 (per sweep)
# max trunc_err = 1.8302e-14, max E_trunc = 3.6948e-13
# chi: [2, 2, 4, 4, 8, 8, 16, 11, 20, 13, 20, 14, 20, 14, 22, 15, 22, 14, 20, 14, 20, 13, 20, 11, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 6 sweeps, max chi=22
# p= 9.267368421052632
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(9.267368421052632)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-75.8562601511309396, max S=0.3403344149132330, age=32, norm_err=9.5e-02
# Current memory usage 274.2MB, wall time: 0.6s
# Delta E = nan, Delta S = 2.4958e-01 (per sweep)
# max trunc_err = 2.3994e-36, max E_trunc = 6.8192e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=np.float64(7.511136108193175e-16)
# INFO    : checkpoint after sweep 2
# energy=-75.8598917913213171, max S=0.5304889302613243, age=32, norm_err=1.4e-04
# Current memory usage 274.4MB, wall time: 0.7s
# Delta E = -3.6316e-03, Delta S = 1.1814e-01 (per sweep)
# max trunc_err = 1.5022e-14, max E_trunc = 3.4135e-03
# chi: [2, 2, 4, 4, 8, 8, 15, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-75.8598917938312809, max S=0.5304885112028882, age=32, norm_err=6.5e-05
# Current memory usage 274.4MB, wall time: 0.7s
# Delta E = -2.5100e-09, Delta S = -6.4247e-06 (per sweep)
# max trunc_err = 1.9738e-14, max E_trunc = 1.7068e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 11, 20, 14, 23, 14, 25, 14, 26, 14, 26, 14, 25, 14, 23, 14, 20, 11, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-75.8598917938316930, max S=0.5304710987675673, age=32, norm_err=3.3e-05
# Current memory usage 274.4MB, wall time: 0.7s
# Delta E = -4.1211e-13, Delta S = -1.4950e-05 (per sweep)
# max trunc_err = 2.6484e-14, max E_trunc = 8.5341e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 11, 20, 14, 23, 14, 25, 14, 26, 14, 26, 14, 25, 14, 23, 14, 20, 11, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-75.8598917938318351, max S=0.5304623742668148, age=32, norm_err=1.6e-05
# Current memory usage 274.4MB, wall time: 0.7s
# Delta E = -1.4211e-13, Delta S = -7.4917e-06 (per sweep)
# max trunc_err = 3.1294e-14, max E_trunc = 4.2671e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 11, 20, 14, 22, 14, 25, 14, 25, 14, 25, 14, 25, 14, 22, 14, 20, 11, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 3.125e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-75.8598917938327872, max S=0.5304536282692246, age=32, norm_err=2.0e-11
# Current memory usage 274.4MB, wall time: 0.5s
# Delta E = -9.5213e-13, Delta S = -7.5188e-06 (per sweep)
# max trunc_err = 6.8505e-15, max E_trunc = 1.5632e-13
# chi: [2, 2, 4, 4, 8, 8, 15, 11, 20, 13, 20, 14, 20, 14, 20, 14, 20, 14, 20, 14, 20, 13, 20, 11, 15, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 6 sweeps, max chi=20
# p= 10.108947368421052
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(10.108947368421052)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-78.6046335635636382, max S=0.3021926030664584, age=32, norm_err=6.8e-02
# Current memory usage 274.4MB, wall time: 0.6s
# Delta E = nan, Delta S = 2.2105e-01 (per sweep)
# max trunc_err = 3.3988e-36, max E_trunc = 7.0682e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=np.float64(7.311343697026888e-16)
# INFO    : checkpoint after sweep 2
# energy=-78.6061443276718421, max S=0.4330497029128987, age=32, norm_err=1.3e-04
# Current memory usage 274.5MB, wall time: 0.7s
# Delta E = -1.5108e-03, Delta S = 8.3087e-02 (per sweep)
# max trunc_err = 1.4623e-14, max E_trunc = 3.5371e-03
# chi: [2, 2, 4, 4, 8, 8, 15, 8, 15, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-78.6061443285996404, max S=0.4330222188470418, age=32, norm_err=6.6e-05
# Current memory usage 274.5MB, wall time: 0.7s
# Delta E = -9.2780e-10, Delta S = -2.5706e-05 (per sweep)
# max trunc_err = 2.7019e-14, max E_trunc = 1.7686e-03
# chi: [2, 2, 4, 4, 8, 8, 16, 10, 20, 13, 21, 13, 21, 13, 23, 13, 23, 13, 23, 13, 21, 13, 20, 11, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-78.6061443285991004, max S=0.4330033094215274, age=32, norm_err=3.3e-05
# Current memory usage 274.5MB, wall time: 0.6s
# Delta E = 5.4001e-13, Delta S = -1.6230e-05 (per sweep)
# max trunc_err = 1.7950e-14, max E_trunc = 8.8431e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 10, 20, 12, 21, 13, 22, 13, 23, 13, 23, 13, 22, 13, 21, 13, 20, 11, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-78.6061443285991146, max S=0.4329938342187453, age=32, norm_err=1.7e-05
# Current memory usage 274.5MB, wall time: 0.6s
# Delta E = -1.4211e-14, Delta S = -8.1313e-06 (per sweep)
# max trunc_err = 2.2272e-14, max E_trunc = 4.4216e-04
# chi: [2, 2, 4, 4, 8, 8, 16, 10, 20, 12, 21, 13, 22, 13, 23, 13, 23, 13, 22, 13, 21, 13, 20, 10, 16, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 3.125e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-78.6061443285983330, max S=0.4329843352357414, age=32, norm_err=4.4e-11
# Current memory usage 274.5MB, wall time: 0.5s
# Delta E = 7.8160e-13, Delta S = -8.1558e-06 (per sweep)
# max trunc_err = 8.9919e-15, max E_trunc = 2.8422e-13
# chi: [2, 2, 4, 4, 8, 8, 13, 10, 19, 11, 19, 12, 19, 12, 20, 12, 20, 12, 19, 12, 19, 11, 19, 10, 13, 8, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 6 sweeps, max chi=20
# p= 10.950526315789475
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(10.950526315789475)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-81.4607160862653217, max S=0.2702477885797392, age=32, norm_err=5.0e-02
# Current memory usage 274.5MB, wall time: 0.6s
# Delta E = nan, Delta S = 1.9730e-01 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.3264e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=4.999999999999999e-16
# INFO    : checkpoint after sweep 2
# energy=-81.4614079899820069, max S=0.3646642260689996, age=32, norm_err=1.3e-04
# ...
# Delta E = -8.5265e-14, Delta S = -1.0013e-05 (per sweep)
# max trunc_err = 1.0697e-14, max E_trunc = 5.0875e-04
# chi: [2, 2, 4, 4, 8, 7, 12, 9, 16, 9, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 9, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-90.4458253997934065, max S=0.2424783496889448, age=32, norm_err=8.6e-06
# Current memory usage 274.7MB, wall time: 0.8s
# Delta E = -2.4158e-13, Delta S = -5.0137e-06 (per sweep)
# max trunc_err = 7.8047e-15, max E_trunc = 2.5438e-04
# chi: [2, 2, 4, 4, 8, 7, 12, 9, 16, 9, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 9, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 1.5625e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 7
# energy=-90.4458253997921133, max S=0.2424725220453289, age=32, norm_err=6.0e-12
# Current memory usage 274.7MB, wall time: 0.5s
# Delta E = 1.2932e-12, Delta S = -5.0237e-06 (per sweep)
# max trunc_err = 1.3031e-14, max E_trunc = 2.8422e-13
# chi: [2, 2, 4, 4, 8, 7, 12, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 8
# energy=-90.4458253997922554, max S=0.2424725220423415, age=32, norm_err=1.7e-14
# Current memory usage 274.7MB, wall time: 0.5s
# Delta E = -1.4211e-13, Delta S = -9.3062e-13 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 7.1054e-14
# chi: [2, 2, 4, 4, 8, 7, 12, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 8 sweeps, max chi=13
# p= 14.316842105263158
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(14.316842105263158)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-93.5342680463307090, max S=0.1828861127683890, age=32, norm_err=1.8e-02
# Current memory usage 274.8MB, wall time: 0.6s
# Delta E = nan, Delta S = 1.3302e-01 (per sweep)
# max trunc_err = 4.4164e-38, max E_trunc = 8.4154e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=np.float64(6.252651793091946e-16)
# INFO    : checkpoint after sweep 2
# energy=-93.5343286174417017, max S=0.2166729070865085, age=32, norm_err=1.4e-04
# Current memory usage 274.8MB, wall time: 0.6s
# Delta E = -6.0571e-05, Delta S = 2.2455e-02 (per sweep)
# max trunc_err = 1.2505e-14, max E_trunc = 4.2089e-03
# chi: [2, 2, 4, 4, 8, 7, 12, 7, 13, 7, 13, 7, 13, 7, 13, 7, 13, 7, 13, 7, 13, 7, 13, 7, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-93.5343286174470592, max S=0.2166252024255069, age=32, norm_err=6.9e-05
# Current memory usage 274.8MB, wall time: 0.7s
# Delta E = -5.3575e-12, Delta S = -4.1350e-05 (per sweep)
# max trunc_err = 1.5093e-14, max E_trunc = 2.1045e-03
# chi: [2, 2, 4, 4, 8, 7, 12, 9, 15, 9, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 9, 15, 9, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-93.5343286174471871, max S=0.2166012448606787, age=32, norm_err=3.4e-05
# Current memory usage 274.8MB, wall time: 0.8s
# Delta E = -1.2790e-13, Delta S = -2.0732e-05 (per sweep)
# max trunc_err = 7.5480e-15, max E_trunc = 1.0522e-03
# chi: [2, 2, 4, 4, 8, 7, 12, 9, 15, 9, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 9, 15, 9, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-93.5343286174472155, max S=0.2165892347130454, age=32, norm_err=1.7e-05
# Current memory usage 274.8MB, wall time: 0.7s
# Delta E = -2.8422e-14, Delta S = -1.0382e-05 (per sweep)
# max trunc_err = 6.8896e-15, max E_trunc = 5.2613e-04
# chi: [2, 2, 4, 4, 8, 7, 12, 9, 15, 9, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 9, 15, 9, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-93.5343286174471302, max S=0.2165832162424903, age=32, norm_err=8.6e-06
# Current memory usage 274.8MB, wall time: 0.8s
# Delta E = 8.5265e-14, Delta S = -5.1983e-06 (per sweep)
# max trunc_err = 5.8501e-15, max E_trunc = 2.6306e-04
# chi: [2, 2, 4, 4, 8, 7, 12, 9, 15, 9, 16, 10, 16, 10, 16, 10, 16, 10, 16, 10, 16, 9, 15, 9, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 1.5625e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 7
# energy=-93.5343286174462918, max S=0.2165771811260382, age=32, norm_err=2.5e-12
# Current memory usage 274.8MB, wall time: 0.5s
# Delta E = 8.3844e-13, Delta S = -5.2085e-06 (per sweep)
# max trunc_err = 9.9482e-15, max E_trunc = 2.7001e-13
# chi: [2, 2, 4, 4, 8, 7, 12, 8, 12, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 12, 8, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 7 sweeps, max chi=13
# p= 15.15842105263158
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(15.15842105263158)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-96.6554295568531785, max S=0.1677913485844674, age=32, norm_err=1.4e-02
# Current memory usage 274.9MB, wall time: 0.6s
# Delta E = nan, Delta S = 1.2199e-01 (per sweep)
# max trunc_err = 8.7384e-36, max E_trunc = 8.6966e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=np.float64(6.54112408189297e-16)
# INFO    : checkpoint after sweep 2
# energy=-96.6554667084618586, max S=0.1951068500068252, age=32, norm_err=1.4e-04
# Current memory usage 274.9MB, wall time: 0.7s
# Delta E = -3.7152e-05, Delta S = 1.8226e-02 (per sweep)
# max trunc_err = 1.3082e-14, max E_trunc = 4.3493e-03
# chi: [2, 2, 4, 4, 8, 6, 12, 7, 12, 7, 12, 7, 12, 7, 12, 7, 12, 7, 12, 7, 12, 7, 12, 7, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-96.6554667084635213, max S=0.1950575650935393, age=32, norm_err=6.9e-05
# Current memory usage 274.9MB, wall time: 0.7s
# Delta E = -1.6627e-12, Delta S = -4.2755e-05 (per sweep)
# max trunc_err = 1.0826e-14, max E_trunc = 2.1747e-03
# chi: [2, 2, 4, 4, 8, 7, 12, 9, 15, 9, 15, 9, 15, 10, 15, 10, 15, 10, 15, 9, 15, 9, 15, 9, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-96.6554667084636208, max S=0.1950328416761629, age=32, norm_err=3.5e-05
# Current memory usage 274.9MB, wall time: 0.7s
# Delta E = -9.9476e-14, Delta S = -2.1421e-05 (per sweep)
# max trunc_err = 9.8996e-15, max E_trunc = 1.0874e-03
# chi: [2, 2, 4, 4, 8, 6, 12, 9, 15, 9, 15, 9, 15, 10, 15, 10, 15, 10, 15, 9, 15, 9, 15, 9, 12, 7, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-96.6554667084629671, max S=0.1950204501133037, age=32, norm_err=1.7e-05
# Current memory usage 274.9MB, wall time: 0.7s
# Delta E = 6.5370e-13, Delta S = -1.0726e-05 (per sweep)
# max trunc_err = 9.7318e-15, max E_trunc = 5.4368e-04
# chi: [2, 2, 4, 4, 8, 6, 12, 9, 15, 9, 15, 9, 15, 10, 15, 10, 15, 10, 15, 9, 15, 9, 15, 9, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-96.6554667084629529, max S=0.1950142410089690, age=32, norm_err=8.6e-06
# Current memory usage 274.9MB, wall time: 0.7s
# Delta E = 1.4211e-14, Delta S = -5.3697e-06 (per sweep)
# max trunc_err = 1.1382e-14, max E_trunc = 2.7184e-04
# chi: [2, 2, 4, 4, 8, 6, 12, 9, 14, 9, 15, 9, 15, 10, 15, 10, 15, 10, 15, 9, 15, 9, 14, 9, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 1.5625e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 7
# energy=-96.6554667084641466, max S=0.1950080139314842, age=32, norm_err=5.4e-13
# Current memory usage 274.9MB, wall time: 0.5s
# Delta E = -1.1937e-12, Delta S = -5.3800e-06 (per sweep)
# max trunc_err = 4.1435e-15, max E_trunc = 1.7053e-13
# chi: [2, 2, 4, 4, 8, 6, 12, 8, 12, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 12, 8, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 8
# energy=-96.6554667084641750, max S=0.1950080139311873, age=32, norm_err=1.1e-14
# Current memory usage 274.9MB, wall time: 0.5s
# Delta E = -2.8422e-14, Delta S = -2.3270e-13 (per sweep)
# max trunc_err = 0.0000e+00, max E_trunc = 9.9476e-14
# chi: [2, 2, 4, 4, 8, 6, 12, 8, 12, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 13, 9, 12, 8, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 8 sweeps, max chi=13
# p= 16.0
# INFO    : Ising_2copy: reading 'L'=16
# INFO    : Ising_2copy: reading 's'=0.5
# INFO    : Ising_2copy: reading 'p'=np.float64(16.0)
# INFO    : SingleSiteDMRGEngine: subconfig 'trunc_params'=Config(<2 options>, 'trunc_params')
# INFO    : SingleSiteDMRGEngine: subconfig 'mixer_params'=Config(<1 options>, 'mixer_params')
# INFO    : activate SubspaceExpansion with initial amplitude 1e-05
# INFO    : SingleSiteDMRGEngine: reading 'max_sweeps'=30
# INFO    : Running sweep with optimization
# INFO    : trunc_params: reading 'chi_max'=100
# INFO    : trunc_params: reading 'svd_min'=1e-07
# INFO    : checkpoint after sweep 1
# energy=-99.8036804864310056, max S=0.1545287384455743, age=32, norm_err=1.2e-02
# Current memory usage 275.1MB, wall time: 0.6s
# Delta E = nan, Delta S = 1.1231e-01 (per sweep)
# max trunc_err = 1.6503e-37, max E_trunc = 8.9801e-03
# chi: [2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : lanczos_params: setting 'P_tol'=np.float64(1.07907233913584e-15)
# INFO    : checkpoint after sweep 2
# energy=-99.8037040689640804, max S=0.1768864430728081, age=32, norm_err=1.4e-04
# Current memory usage 275.1MB, wall time: 0.6s
# Delta E = -2.3583e-05, Delta S = 1.4966e-02 (per sweep)
# max trunc_err = 2.1581e-14, max E_trunc = 4.4910e-03
# chi: [2, 2, 4, 4, 8, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: reading 'max_E_err'=1e-12
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 3
# energy=-99.8037040689640804, max S=0.1768356928021939, age=32, norm_err=6.9e-05
# Current memory usage 275.1MB, wall time: 0.7s
# Delta E = 0.0000e+00, Delta S = -4.4059e-05 (per sweep)
# max trunc_err = 1.9009e-14, max E_trunc = 2.2455e-03
# chi: [2, 2, 4, 4, 8, 6, 12, 9, 13, 9, 15, 9, 15, 9, 15, 9, 15, 9, 15, 9, 15, 9, 13, 9, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 4
# energy=-99.8037040689637251, max S=0.1768102502280435, age=32, norm_err=3.5e-05
# Current memory usage 275.1MB, wall time: 0.7s
# Delta E = 3.5527e-13, Delta S = -2.2065e-05 (per sweep)
# max trunc_err = 1.6056e-14, max E_trunc = 1.1228e-03
# chi: [2, 2, 4, 4, 8, 6, 12, 8, 13, 9, 15, 9, 15, 9, 15, 9, 15, 9, 15, 9, 15, 9, 13, 8, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 5
# energy=-99.8037040689637394, max S=0.1767975010520180, age=32, norm_err=1.7e-05
# Current memory usage 275.1MB, wall time: 0.6s
# Delta E = -1.4211e-14, Delta S = -1.1047e-05 (per sweep)
# max trunc_err = 1.5491e-14, max E_trunc = 5.6139e-04
# chi: [2, 2, 4, 4, 8, 6, 12, 8, 13, 9, 15, 9, 15, 9, 15, 9, 15, 9, 15, 9, 15, 9, 13, 8, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 6
# energy=-99.8037040689631283, max S=0.1767911136372543, age=32, norm_err=8.7e-06
# Current memory usage 275.1MB, wall time: 0.7s
# Delta E = 6.1107e-13, Delta S = -5.5300e-06 (per sweep)
# max trunc_err = 1.4748e-14, max E_trunc = 2.8070e-04
# chi: [2, 2, 4, 4, 8, 6, 12, 8, 13, 8, 15, 9, 15, 9, 15, 9, 15, 9, 15, 9, 15, 8, 13, 8, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine: Convergence criterion reached with enabled mixer. Disable mixer and continue.
# INFO    : deactivate SubspaceExpansion with final amplitude 1.5625e-07
# INFO    : Running sweep with optimization
# INFO    : checkpoint after sweep 7
# energy=-99.8037040689629151, max S=0.1767847075228011, age=32, norm_err=1.2e-12
# Current memory usage 275.1MB, wall time: 0.5s
# Delta E = 2.1316e-13, Delta S = -5.5401e-06 (per sweep)
# max trunc_err = 9.7145e-15, max E_trunc = 2.9843e-13
# chi: [2, 2, 4, 4, 8, 6, 12, 7, 12, 7, 12, 8, 12, 8, 13, 8, 13, 8, 12, 8, 12, 7, 12, 7, 12, 6, 8, 4, 4, 2, 2]
# ================================================================================
# INFO    : SingleSiteDMRGEngine finished after 7 sweeps, max chi=13
#
# ---------------------------------------------------
# 81.21048498153687

# %% [markdown]
# ### get the matrix product density operator from the groundstates

# %%
def MPS_drop_charge(psi, charge=None, chinfo=None, permute_p_leg=True):
    psi_c = psi.copy()
    psi_c.chinfo = chinfo = npc.ChargeInfo.drop(chinfo, charge=charge)
    if permute_p_leg is None and chinfo.qnumber == 0:
        permute_p_leg = True
    for i, B in enumerate(psi_c._B):
        psi_c._B[i] = B = B.drop_charge(charge=charge, chinfo=chinfo)
        psi_c.sites[i] = site = copy.copy(psi.sites[i])
        if permute_p_leg:
            if permute_p_leg is True:
                perm = tenpy.tools.misc.inverse_permutation(site.perm)
            else:
                perm = permute_p_leg
            psi_c._B[i] = B = B.permute(perm, 'p')
        else:
            perm = None
        site.change_charge(B.get_leg('p'), perm) # in place
    psi_c.test_sanity()
    return psi_c
    
def double_to_mpo(psi,L):
    Ws=[]
    psi=MPS_drop_charge(psi)
    for i in range(L):
        a=npc.tensordot(psi.get_B(2*i),psi.get_B(2*i+1),axes=(2,0))
        a.itranspose((0,3,1,2))
        a_array=a.to_ndarray().astype(np.float64)
        
        Ws.append(a_array)
    return Ws

# %%
mpo_arrays=[]
L=16
for state in states:
    state = MPS_drop_charge(state)
    W = double_to_mpo(state,L)
    mpo_arrays.append(W)

# %%
np.save('../data/groundstates_Z2_L'+str(L), np.array(mpo_arrays, dtype=object), allow_pickle=True)
